# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        # print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import shutil
import cv2
from albumentations import (
    HorizontalFlip, VerticalFlip, RandomBrightnessContrast, Rotate, ShiftScaleRotate
)
from albumentations import Compose
from tqdm import tqdm
import tensorflow as tf

base_dir = '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/'
output_base_dir = '/kaggle/working/augmented_data/'

# Delete and recreate output directory
if os.path.exists(output_base_dir):
    shutil.rmtree(output_base_dir)
os.makedirs(output_base_dir, exist_ok=True)

# Define the augmentation pipeline
augmentor = Compose([
    HorizontalFlip(p=0.5),
    VerticalFlip(p=0.5),
    RandomBrightnessContrast(p=0.2),
    Rotate(limit=20, p=0.5),
    ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5)
])

for subset in ['Training']:
    subset_dir = os.path.join(base_dir, subset)
    output_subset_dir = os.path.join(output_base_dir, subset)

    if not os.path.exists(output_subset_dir):
        os.makedirs(output_subset_dir)

    class_dirs = [os.path.join(subset_dir, cls) for cls in os.listdir(subset_dir)]
    class_counts = {cls: len(os.listdir(cls)) for cls in class_dirs}
    print(class_counts)

    max_class = max(class_counts, key=class_counts.get)
    max_count = class_counts[max_class]

    print(f"{subset}: maximum class - {os.path.basename(max_class)} and count - {max_count}")

    for class_dir in class_dirs:
        class_name = os.path.basename(class_dir)
        output_class_dir = os.path.join(output_subset_dir, class_name)

        if not os.path.exists(output_class_dir):
            os.makedirs(output_class_dir)

        images = [os.path.join(class_dir, fname) for fname in os.listdir(class_dir)]
        num_images_to_generate = max_count - len(images)

        # Copy original images to output
        for img_path in images:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            cv2.imwrite(os.path.join(output_class_dir, os.path.basename(img_path)), cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

        # Apply augmentation
        for img_path in images:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # Apply augmentations to each image
            for i in range(num_images_to_generate):
                augmented = augmentor(image=img)
                aug_img = augmented['image']
                aug_img_name = f"{os.path.splitext(os.path.basename(img_path))[0]}_aug{i}.jpg"
                aug_img_path = os.path.join(output_class_dir, aug_img_name)

                # Save the augmented image
                cv2.imwrite(aug_img_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR), [int(cv2.IMWRITE_JPEG_QUALITY), 80])

    print(f"{subset} augmentation done")

# %%
import os
import shutil
import cv2
from albumentations import (
    HorizontalFlip, VerticalFlip, RandomBrightnessContrast, Rotate, ShiftScaleRotate
)
from albumentations import Compose
from tqdm import tqdm
import tensorflow as tf

base_dir = '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/'
output_base_dir = '/kaggle/working/augmented_data/'

# Delete and recreate output directory
if os.path.exists(output_base_dir):
    shutil.rmtree(output_base_dir)
os.makedirs(output_base_dir, exist_ok=True)

# Define the augmentation pipeline
augmentor = Compose([
    HorizontalFlip(p=0.5),
    VerticalFlip(p=0.5),
    RandomBrightnessContrast(p=0.2),
    Rotate(limit=20, p=0.5),
    ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5)
])

for subset in ['Training']:
    subset_dir = os.path.join(base_dir, subset)
    output_subset_dir = os.path.join(output_base_dir, subset)

    if not os.path.exists(output_subset_dir):
        os.makedirs(output_subset_dir)

    class_dirs = [os.path.join(subset_dir, cls) for cls in os.listdir(subset_dir)]
    class_counts = {cls: len(os.listdir(cls)) for cls in class_dirs}
    print(class_counts)

    max_class = max(class_counts, key=class_counts.get)
    max_count = class_counts[max_class]

    print(f"{subset}: maximum class - {os.path.basename(max_class)} and count - {max_count}")

    for class_dir in class_dirs:
        class_name = os.path.basename(class_dir)
        output_class_dir = os.path.join(output_subset_dir, class_name)

        if not os.path.exists(output_class_dir):
            os.makedirs(output_class_dir)

        images = [os.path.join(class_dir, fname) for fname in os.listdir(class_dir)]
        num_images_to_generate = max_count - len(images)
        # print(f"{class_dir}: {num_images_to_generate}")

        # # Calculate how many augmentations to generate per image
        # num_augmentations_per_image = num_images_to_generate // len(images) if len(images) > 0 else 0

        print(f"Class '{class_name}': {len(images)} images available, {num_images_to_generate} more needed.")
        # print(f"Generating {num_augmentations_per_image} augmentations per image.")


        augmented_images = 0
        for img_path in images:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            if augmented_images >= num_images_to_generate:
               break




        # Copy original images to output
        # for img_path in images:
            # print(img_path)
            # img = cv2.imread(img_path)
            # img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            # cv2.imwrite(os.path.join(output_class_dir, os.path.basename(img_path)), cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

    #     # Apply augmentation
    #     for img_path in images:
    #         img = cv2.imread(img_path)
    #         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #         # Apply augmentations to each image
    #         for i in range(num_augmentations_per_image):
    #             augmented = augmentor(image=img)
    #             aug_img = augmented['image']
    #             aug_img_name = f"{os.path.splitext(os.path.basename(img_path))[0]}_aug{i}.jpg"
    #             aug_img_path = os.path.join(output_class_dir, aug_img_name)

    #             # Save the augmented image
    #             cv2.imwrite(aug_img_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR), [int(cv2.IMWRITE_JPEG_QUALITY), 80])

    # print(f"{subset} augmentation done")

# %%
import os
import shutil
import cv2
from albumentations import (
    HorizontalFlip, VerticalFlip, RandomBrightnessContrast, Rotate, ShiftScaleRotate
)
from albumentations import Compose
import random
from tqdm import tqdm


base_dir = '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/'
output_base_dir = '/kaggle/working/balanced_data/'


if os.path.exists(output_base_dir):
    shutil.rmtree(output_base_dir)
os.makedirs(output_base_dir, exist_ok=True)


augmentor = Compose([
    HorizontalFlip(p=0.5),
    VerticalFlip(p=0.5),
    RandomBrightnessContrast(p=0.2),
    Rotate(limit=20, p=0.5),
    ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5)
])


total_augmentations = 0


for subset in ['Training','Validation','Testing']:
    subset_dir = os.path.join(base_dir, subset)
    output_subset_dir = os.path.join(output_base_dir, subset)

    if not os.path.exists(output_subset_dir):
        os.makedirs(output_subset_dir)

   
    class_dirs = [os.path.join(subset_dir, cls) for cls in os.listdir(subset_dir)]
    class_counts = {cls: len(os.listdir(cls)) for cls in class_dirs}
    print(class_counts)

    
    max_class = max(class_counts, key=class_counts.get)
    max_count = class_counts[max_class]
    print(f"{subset}: maximum class - {os.path.basename(max_class)} and count - {max_count}")

    
    for class_dir in class_dirs:
        class_name = os.path.basename(class_dir)
        output_class_dir = os.path.join(output_subset_dir, class_name)

        if not os.path.exists(output_class_dir):
            os.makedirs(output_class_dir)

        images = [os.path.join(class_dir, fname) for fname in os.listdir(class_dir)]
        num_images_to_generate = max_count - len(images)  # How many augmentations are needed

        print(f"Class '{class_name}': {len(images)} images available, {num_images_to_generate} more needed.")

        
        for img_path in images:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            cv2.imwrite(os.path.join(output_class_dir, os.path.basename(img_path)),
                        cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

        
        class_augmentations = 0  
        if num_images_to_generate > 0:
           
            selected_images = random.sample(images, num_images_to_generate)

            
            for i, img_path in enumerate(selected_images):
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

                
                augmented = augmentor(image=img)
                aug_img = augmented['image']
                aug_img_name = f"{os.path.splitext(os.path.basename(img_path))[0]}_aug{i}.jpg"
                aug_img_path = os.path.join(output_class_dir, aug_img_name)

            
                cv2.imwrite(aug_img_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR),
                            [int(cv2.IMWRITE_JPEG_QUALITY), 80])

                class_augmentations += 1  

        total_augmentations += class_augmentations  
        print(f"Augmentation for class '{class_name}' completed. {class_augmentations} new images generated.")

    print(f"{subset} augmentation done.")


print(f"Total augmentations across all classes: {total_augmentations}")
# Out:
# {'/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Training/Late_Blight': 1132, '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Training/Early_Blight': 1303, '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Training/Healthy': 816}
# Training: maximum class - Early_Blight and count - 1303
# Class 'Late_Blight': 1132 images available, 171 more needed.
# Augmentation for class 'Late_Blight' completed. 171 new images generated.
# Class 'Early_Blight': 1303 images available, 0 more needed.
# Augmentation for class 'Early_Blight' completed. 0 new images generated.
# Class 'Healthy': 816 images available, 487 more needed.
# Augmentation for class 'Healthy' completed. 487 new images generated.
# Training augmentation done.
# {'/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Late_Blight': 151, '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Early_Blight': 163, '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/Healthy': 102}
# Validation: maximum class - Early_Blight and count - 163
# Class 'Late_Blight': 151 images available, 12 more needed.
# Augmentation for class 'Late_Blight' completed. 12 new images generated.
# Class 'Early_Blight': 163 images available, 0 more needed.
# Augmentation for class 'Early_Blight' completed. 0 new images generated.
# Class 'Healthy': 102 images available, 61 more needed.
# Augmentation for class 'Healthy' completed. 61 new images generated.
# Validation augmentation done.
# {'/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Testing/Late_Blight': 141, '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Testing/Early_Blight': 162, '/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Testing/Healthy': 102}
# Testing: maximum class - Early_Blight and count - 162
# Class 'Late_Blight': 141 images available, 21 more needed.
# Augmentation for class 'Late_Blight' completed. 21 new images generated.
# Class 'Early_Blight': 162 images available, 0 more needed.
# Augmentation for class 'Early_Blight' completed. 0 new images generated.
# Class 'Healthy': 102 images available, 60 more needed.
# Augmentation for class 'Healthy' completed. 60 new images generated.
# Testing augmentation done.
# Total augmentations across all classes: 812

# %%
# !zip -r balanced_data.zip /kaggle/working/balanced_data
# Out:
#   adding: kaggle/working/balanced_data/ (stored 0%)
#   adding: kaggle/working/balanced_data/Training/ (stored 0%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/ (stored 0%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_633.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_989.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_81_aug166.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_414.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_473.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_210.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_314.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_384.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_789.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_678.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_953_aug11.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_4.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_168_aug116.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_800_aug1.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_773.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_430.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_793.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_876.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_269.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_373_aug13.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1044.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_696.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_516_aug89.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_85.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_168.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_20.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_801.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_805.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_185.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1080.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_94.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_237.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_398_aug48.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_943.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_133.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_425.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_677.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_915_aug17.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_637.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_74.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_761.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_763.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_119.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_319.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_459.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_872.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_882.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_724.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_710.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_968.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_321.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_660.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_11_aug138.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_167.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_336.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_891.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1050.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_952.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_982.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_896.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_624.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_316.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_939.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_54.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_272.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_47.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_401_aug4.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_975.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_881.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_924.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_620.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_996.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_992.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_22.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_995.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_680.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1082.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_856.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_524_aug40.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_60.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_717.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_948.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_686.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_452_aug62.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_918.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1086_aug44.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_290.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_531.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_213.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_239.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_576.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_922.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_476.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_770.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_458.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_344.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_97.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_42_aug97.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1015.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1115.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_912.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_254.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_890.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_301.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_374.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_349.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_636.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_378.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_44.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_868.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_223.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1077.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_58.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_893.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1005.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_79.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_487.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_453.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_888.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_452.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_220.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_376_aug31.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_534.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_440.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_707.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_188.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1090.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_742.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_107.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_562.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1132.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_286.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_945.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_42.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_72.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_525_aug42.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_697.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1027.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_661.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1076.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_974.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_143.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_889.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_263.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_134.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_917_aug15.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1122.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_180.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_179.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_471.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_334_aug130.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_575.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_368.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_443_aug3.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_965.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_907_aug112.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1130.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_442.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_566.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1114.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_198.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_16.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_934.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1125.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_516.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_774.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_580.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_464.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_308.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_62.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_267.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_546.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_130.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1066.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_687.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_142.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_824.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_644.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_638.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_680_aug170.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1003.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_750.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_899.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_702.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_767.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_905.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_978.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_69.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_780.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_712.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1064.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_880.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_379.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_364.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1067.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_523.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_219.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_403_aug18.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_504.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_579.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_983.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1118.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_191.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_565.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_16_aug38.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_608.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_491.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_545.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_641.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1002.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_391.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_810.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_151.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_202.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_615.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_486.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_733.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_813.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_387.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_102.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_543.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_80.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_340_aug148.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_654.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_217.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1025.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_477.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_302_aug39.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_226.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_999.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_272_aug167.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1085.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_540.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_31.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_305.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_406.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1087.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_573.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_33.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_420.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1089.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_74_aug96.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1111.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_109.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_236.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_969.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1035.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1056.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_280.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_171.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_454_aug59.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_583_aug117.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_786.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_70.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_164.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1014.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_162.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_947.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_751.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_270_aug141.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_584.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_607.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_220_aug33.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_963.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_956.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_782.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_863.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_594.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_363.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_211.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_174.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_681.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_528.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_156_aug12.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_350.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_783.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_879.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_369.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_598.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_55.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_628.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_635.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_488.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_266.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_184.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_875.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_389.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_606.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_809.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1124.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1091.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_256.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_228.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_769.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_673_aug92.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_193.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_529.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_365.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_19.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_95.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_762.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_730.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_83.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_483_aug123.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_688.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_946.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_63.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_48.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_182.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_12.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_170.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_938.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_642.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1048.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1116.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1092.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_146.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_405.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_190.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_542_aug98.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_849_aug91.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_431.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_298_aug41.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1047.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_64.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_587.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_760_aug140.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_297.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_249.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_208.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_978_aug154.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_584_aug118.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_126.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_874_aug155.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_862.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_326.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_395.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_502.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_698.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1108.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_525.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_855.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_417.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_716.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_9.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_989_aug163.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_86_aug122.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_212_aug47.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_747_aug9.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_245.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_147.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_212.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_158.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_949.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_380.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_242.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1075_aug134.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_877.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_766_aug74.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_78.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_853.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_271.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_871_aug52.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_43.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1009.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_864.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_923.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_416.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_937.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_140.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_929.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_595.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_908.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_11.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_539.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_285.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_287.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_825.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_139.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_667.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_674_aug145.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_101.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_46.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_404.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_331.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_251.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_13_aug54.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_909.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_670.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_509.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1110.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_121.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_447.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_714.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_320.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_3.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1046.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_35.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_753.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_169.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1117.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_659.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_713_aug136.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_289.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_555.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_630.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_271_aug104.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_521.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_394.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_183.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_626.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_422.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_274.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_200.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_82.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_988.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_619.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_230.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_418.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_352_aug80.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1112.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_849.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_227.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_787.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_354.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1018.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_691.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_156.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_76.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_116.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_987.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1104.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1023.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_225.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_288.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_756.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1097.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_243.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_788.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_27.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_51.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_914.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_18.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_468_aug169.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_282.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_927_aug142.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_841.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_682.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_103.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_666.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_401.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1062.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_277.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_532.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_283.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_199.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_559.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_324.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_592.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_609.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_581.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_178.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_878.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_990.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1084.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_980_aug53.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_791.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1098.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_68.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_481.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_980.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_589.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_797.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_533.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_1045.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_837.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_500.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_129.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_172.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_595_aug137.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_186.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_651_aug68.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_335.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_713.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_313.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_201.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_98.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_552.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_728.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_657.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_984.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_979.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_764.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_362.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_972_aug81.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_883.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_463.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_564.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_685.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_84.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_655.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_734.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_844.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Training/Late_Blight/Late_Blight_15.jpg (deflated 4%)
# ...
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_58.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_23.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_57.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_11.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_84.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_163.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_151.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_61.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_87.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_72.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_128.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_158.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_77.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Early_Blight/Early_Blight_25.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/ (stored 0%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_77.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_40.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_34_aug20.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_99.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_88.jpg (deflated 7%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_61.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_58_aug53.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_4.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_102_aug6.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_64_aug46.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_21.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_68.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_19.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_22.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_49.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_75_aug42.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_2.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_7.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_74.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_85.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_76_aug60.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_46_aug1.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_37.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_8_aug27.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_14.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_9.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_80_aug41.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_18.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_45.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_53.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_85_aug58.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_22_aug38.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_43.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_11.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_52_aug32.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_48_aug22.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_81.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_93.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_33.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_88_aug8.jpg (deflated 3%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_86_aug0.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_42.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_60_aug16.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_3.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_30.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_34.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_94.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_32_aug52.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_17.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_20_aug51.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_79_aug25.jpg (deflated 3%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_30_aug47.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_74_aug30.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_26.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_59.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_87.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_7_aug56.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_32.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_91.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_59_aug28.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_50_aug18.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_25.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_33_aug55.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_98.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_1.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_58.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_1_aug21.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_63.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_63_aug40.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_100.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_28_aug39.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_26_aug5.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_16.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_83_aug17.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_89.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_66.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_44.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_21_aug7.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_14_aug14.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_71.jpg (deflated 4%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_51.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_20.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_84.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_95.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_57.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_69.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_31_aug54.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_75.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_27.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_36.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_61_aug4.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_67.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_3_aug31.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_6.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_28.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_90.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_36_aug37.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_50.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_29.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_56_aug26.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_73.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_79.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_86.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_80.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_37_aug44.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_70.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_102.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_52.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_78.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_2_aug36.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_35.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_53_aug48.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_56.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_29_aug29.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_8.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_13_aug9.jpg (deflated 3%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_4_aug24.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_24.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_35_aug33.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_82_aug23.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_48.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_11_aug59.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_41_aug12.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_31.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_81_aug3.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_77_aug45.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_82.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_62.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_38.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_13.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_62_aug15.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_19_aug2.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_83.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_92.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_65.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_76.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_55.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_51_aug11.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_39_aug43.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_46.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_12.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_23.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_10_aug35.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_97.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_16_aug13.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_90_aug34.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_60.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_64.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_72.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_96.jpg (deflated 6%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_10.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_47_aug49.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_42_aug19.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_5.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_92_aug10.jpg (deflated 1%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_39.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_89_aug57.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_101.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_47.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_54.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_43_aug50.jpg (deflated 2%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_15.jpg (deflated 5%)
#   adding: kaggle/working/balanced_data/Validation/Healthy/Healthy_41.jpg (deflated 5%)

# %%
# !ls
# Out:
# balanced_data  balanced_data.zip

# %%
from IPython.display import FileLink
FileLink(r'balanced_data.zip')
# Out:
# /kaggle/working/balanced_data.zip
